# %%
from bs4 import BeautifulSoup
import requests, time
import html5lib
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import random

# %%
session = requests.Session()
session.headers = {
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7)",
}

# %%
# crawl xe cu
links = []
for p in range(1, 100):
    url = f"https://oto.com.vn/mua-ban-xe/p{p}"
    html = session.get(url)
    html.encoding = 'utf-8'
    html = html.text
    soup = BeautifulSoup(html, 'html5lib')
    for i in soup.find_all("div", class_="dev-item-car"):
        href = i.find("a").get("href")
        if href.startswith("/mua-ban-xe"):
            links.append(href)
len(links)
# Out:
# 1485

# %%
data = []
for link in links:
    try:
        url = "https://oto.com.vn" + link
        car_info = {'URL' : url}
        html = session.get(url)
        html.encoding = 'utf-8'
        html = html.text
        soup = BeautifulSoup(html, 'html5lib')

        title = soup.find('h1', class_='title-detail').get_text(strip=True)
        car_info['Tên xe'] = title

        price = soup.find('input', {'id': 'hddPrice'}).get('value')
        car_info['Giá'] = price

        numberOfSeat = soup.find('input', {'id': 'numberOfSeat'}).get('value')
        car_info['Số ghế'] = numberOfSeat

        datePosted = soup.find('span', class_='date').get_text(strip=True)
        car_info['Ngày đăng'] = datePosted

        items = soup.select('ul.list-info li')
        for item in items:
            label_tag = item.find('label', class_='label')
            label = label_tag.get_text(strip=True).replace(':', '') if label_tag else ''
            value = item.get_text(strip=True).replace(label_tag.get_text(strip=True), '').strip()
            car_info[label] = value
        data.append(car_info)

    except requests.exceptions.Timeout:
        print(f"Timeout khi lấy: {url}")
    except requests.exceptions.RequestException as e:
        print(f"Lỗi khác ở {url}: {e}")
        
    time.sleep(random.uniform(0.2, 0.6))

# %%
len(data)
# Out:
# 1484

# %%
df = pd.DataFrame(data)
df
# Out:
#                                                     URL  \
# 0     https://oto.com.vn/mua-ban-xe-hyundai-kona-ha-...
# 1     https://oto.com.vn/mua-ban-xe-ford-everest-ha-...
# 2     https://oto.com.vn/mua-ban-xe-ford-transit-hcm...
# 3     https://oto.com.vn/mua-ban-xe-mazda-3-ha-noi/s...
# 4     https://oto.com.vn/mua-ban-xe-mitsubishi-xpand...
# ...                                                 ...
# 1479  https://oto.com.vn/mua-ban-xe-nissan-tiida-hcm...
# 1480  https://oto.com.vn/mua-ban-xe-mazda-3-lam-dong...
# 1481  https://oto.com.vn/mua-ban-xe-porsche-cayenne-...
# 1482  https://oto.com.vn/mua-ban-xe-mazda-6-ha-noi/2...
# 1483  https://oto.com.vn/mua-ban-xe-toyota-vios-hai-...
#
#                                      Tên xe         Giá  Số ghế  Năm SX  \
# 0         Hyundai Kona 2.0 AT Đặc biệt 2019   450000000       5    2019
# 1     Ford Everest Titanium 2.0 AT 4x2 2023  1225000000       7    2023
# 2                         Ford Transit 2022   715000000      16    2022
# 3            Mazda 3 Sedan 1.5L Luxury 2020   499000000       5    2020
# 4            Mitsubishi Xpander 1.5 MT 2019   420000000       7    2019
# ...                                     ...         ...     ...     ...
# 1479                  Nissan Tiida 1.6 2006   165000000       5    2006
# 1480                           Mazda 3 2022   550000000       5    2022
# 1481            Porsche Cayenne 3.6 V6 2011   960000000       5    2011
# 1482                    Mazda 6 2.0 AT 2020   580000000       4    2020
# 1483                       Toyota Vios 2013   175000000       5    2013
#
#      Nhiên liệu    Kiểu dáng Tình trạng    Km đã đi      Hộp số     Xuất xứ  \
# 0      Máy xăng          SUV      Xe cũ   80.000 km  Số tự động  Trong nước
# 1       Máy dầu          SUV      Xe cũ   22.000 km  Số tự động   Nhập khẩu
# 2       Máy dầu  Van/Minivan      Xe cũ   40.000 km      Số sàn  Trong nước
# 3      Máy xăng        Sedan      Xe cũ    3.200 km  Số tự động  Trong nước
# 4      Máy xăng          MPV      Xe cũ   76.000 km  Số tự động   Nhập khẩu
# ...         ...          ...        ...         ...         ...         ...
# 1479   Máy xăng        Sedan      Xe cũ  143.200 km  Số tự động   Nhập khẩu
# 1480   Máy xăng        Sedan      Xe cũ    7.900 km  Số tự động   Nhập khẩu
# 1481   Máy xăng          SUV      Xe cũ   96.000 km  Số tự động   Nhập khẩu
# 1482   Máy xăng        Sedan      Xe cũ  110.000 km  Số tự động  Trong nước
# 1483   Máy xăng        Sedan      Xe cũ         NaN      Số sàn         NaN
#
#                  Tỉnh thành   Ngày đăng
# 0      Nam Từ Liêm - Hà Nội  12/07/2025
# 1        Hoàng Mai - Hà Nội  03/06/2025
# 2          Tân Phú - Tp.HCM  15/06/2025
# 3        Hoàng Mai - Hà Nội  08/04/2025
# 4     Thuận An - Bình Dương  12/02/2025
# ...                     ...         ...
# 1479      Tân Bình - Tp.HCM  14/01/2025
# 1480               Lâm Đồng  07/04/2025
# 1481                 Tp.HCM  22/01/2025
# 1482                 Hà Nội  22/01/2025
# 1483              Hải Dương  14/09/2025
#
# [1484 rows x 13 columns]

# %%
# crawl xe moi
new_links = []

for p in range(1, 100):
    url = f'https://oto.com.vn/mua-ban-xe-moi/p{p}'
    html = session.get(url).text
    soup = BeautifulSoup(html, 'html5lib')
    for i in soup.find_all("div", class_="dev-item-car"):
        href = i.find("a").get("href")
        if href.startswith("/mua-ban-xe"):
            new_links.append(href)

# for link in new_links:
#     print(link)
len(new_links)
# Out:
# 1485

# %%
new_car_data = []

for link in new_links:
    try:
        url = f'https://oto.com.vn' + link

        car_info = {'URL': url}

        html = session.get(url)
        html.encoding = 'utf-8'
        html = html.text
        soup = BeautifulSoup(html, 'html5lib')

        title = soup.find('h1', class_='title-detail').get_text(strip=True)
        car_info['Tên xe'] = title

        price = soup.find('input', {'id': 'hddPrice'}).get('value')
        car_info['Giá'] = price

        numberOfSeat = soup.find('input', {'id': 'numberOfSeat'}).get('value')
        car_info['Số ghế'] = numberOfSeat

        datePosted = soup.find('span', class_='date').get_text(strip=True)
        car_info['Ngày đăng'] = datePosted

        items = soup.select('ul.list-info li')
        for item in items:
            label_tag = item.find('label', class_='label')
            label = label_tag.get_text(strip=True).replace(':', '') if label_tag else ''
            value = item.get_text(strip=True).replace(label_tag.get_text(strip=True), '').strip()
            car_info[label] = value
        new_car_data.append(car_info)

    except requests.exceptions.Timeout:
        print(f"Timeout khi lấy: {url}")
    except requests.exceptions.RequestException as e:
        print(f"Lỗi khác ở {url}: {e}")
        
    time.sleep(random.uniform(0.2, 0.6))

# %%
len(new_car_data)
# Out:
# 1485

# %%
new_car_df = pd.DataFrame(new_car_data)
new_car_df
# Out:
#                                                     URL  \
# 0     https://oto.com.vn/mua-ban-xe-vinfast-vf5-ha-n...
# 1     https://oto.com.vn/mua-ban-xe-vinfast-vf3-ha-n...
# 2     https://oto.com.vn/mua-ban-xe-mercedes-benz-gl...
# 3     https://oto.com.vn/mua-ban-xe-vinfast-herio-gr...
# 4     https://oto.com.vn/mua-ban-xe-vinfast-vf7-ha-n...
# ...                                                 ...
# 1480  https://oto.com.vn/mua-ban-xe-mazda-cx-30-hcm/...
# 1481  https://oto.com.vn/mua-ban-xe-kia-sportage-hcm...
# 1482  https://oto.com.vn/mua-ban-xe-kia-carnival-hcm...
# 1483  https://oto.com.vn/mua-ban-xe-kia-carnival-hcm...
# 1484  https://oto.com.vn/mua-ban-xe-mazda-cx-5-hcm/k...
#
#                                  Tên xe         Giá  Số ghế  Năm SX  \
# 0                 VinFast VF5 Plus 2025   485000000       7    2025
# 1                     VinFast VF 3 2025   275000000       4    2025
# 2     Mercedes-Benz GLS 450 4Matic 2025  5689000000       7    2025
# 3              VinFast Herio Green 2025   419000000       5    2025
# 4                 VinFast VF7 Plus 2025   861000000       0    2025
# ...                                 ...         ...     ...     ...
# 1480       Mazda CX-30 2.0L Luxury 2024   639000000       5    2024
# 1481   Kia Sportage 2.0D Signature 2025   910000000       5    2025
# 1482                  Kia Carnival 2025  1799000000       7    2025
# 1483                  Kia Carnival 2025  1799000000       7    2025
# 1484       Mazda CX-5 2.0L Premium 2025   784000000       5    2025
#
#      Nhiên liệu    Kiểu dáng Tình trạng      Hộp số     Xuất xứ  \
# 0          Điện          SUV     Xe mới  Số tự động  Trong nước
# 1          Điện  Van/Minivan     Xe mới  Số tự động  Trong nước
# 2      Máy xăng          SUV     Xe mới  Số tự động   Nhập khẩu
# 3          Điện          SUV     Xe mới  Số tự động  Trong nước
# 4          Điện          SUV     Xe mới  Số tự động  Trong nước
# ...         ...          ...        ...         ...         ...
# 1480   Máy xăng    Crossover     Xe mới  Số tự động  Trong nước
# 1481    Máy dầu          SUV     Xe mới  Số tự động  Trong nước
# 1482     Hybrid          MPV     Xe mới  Số tự động  Trong nước
# 1483     Hybrid          MPV     Xe mới  Số tự động  Trong nước
# 1484   Máy xăng          SUV     Xe mới  Số tự động  Trong nước
#
#                  Tỉnh thành   Ngày đăng
# 0     Hai Bà Trưng - Hà Nội  26/03/2025
# 1     Hai Bà Trưng - Hà Nội  30/07/2025
# 2     Hồng Bàng - Hải Phòng  29/07/2025
# 3        Long Biên - Hà Nội  22/06/2025
# 4     Hai Bà Trưng - Hà Nội  07/05/2025
# ...                     ...         ...
# 1480       Thủ Đức - Tp.HCM  01/04/2025
# 1481       Thủ Đức - Tp.HCM  30/08/2025
# 1482       Thủ Đức - Tp.HCM  16/01/2025
# 1483       Thủ Đức - Tp.HCM  22/06/2025
# 1484       Thủ Đức - Tp.HCM  12/01/2025
#
# [1485 rows x 12 columns]

# %%
all_car_df = pd.concat([df, new_car_df], ignore_index=True)
all_car_df
# Out:
#                                                     URL  \
# 0     https://oto.com.vn/mua-ban-xe-hyundai-kona-ha-...
# 1     https://oto.com.vn/mua-ban-xe-ford-everest-ha-...
# 2     https://oto.com.vn/mua-ban-xe-ford-transit-hcm...
# 3     https://oto.com.vn/mua-ban-xe-mazda-3-ha-noi/s...
# 4     https://oto.com.vn/mua-ban-xe-mitsubishi-xpand...
# ...                                                 ...
# 2964  https://oto.com.vn/mua-ban-xe-mazda-cx-30-hcm/...
# 2965  https://oto.com.vn/mua-ban-xe-kia-sportage-hcm...
# 2966  https://oto.com.vn/mua-ban-xe-kia-carnival-hcm...
# 2967  https://oto.com.vn/mua-ban-xe-kia-carnival-hcm...
# 2968  https://oto.com.vn/mua-ban-xe-mazda-cx-5-hcm/k...
#
#                                      Tên xe         Giá  Số ghế  Năm SX  \
# 0         Hyundai Kona 2.0 AT Đặc biệt 2019   450000000       5    2019
# 1     Ford Everest Titanium 2.0 AT 4x2 2023  1225000000       7    2023
# 2                         Ford Transit 2022   715000000      16    2022
# 3            Mazda 3 Sedan 1.5L Luxury 2020   499000000       5    2020
# 4            Mitsubishi Xpander 1.5 MT 2019   420000000       7    2019
# ...                                     ...         ...     ...     ...
# 2964           Mazda CX-30 2.0L Luxury 2024   639000000       5    2024
# 2965       Kia Sportage 2.0D Signature 2025   910000000       5    2025
# 2966                      Kia Carnival 2025  1799000000       7    2025
# 2967                      Kia Carnival 2025  1799000000       7    2025
# 2968           Mazda CX-5 2.0L Premium 2025   784000000       5    2025
#
#      Nhiên liệu    Kiểu dáng Tình trạng   Km đã đi      Hộp số     Xuất xứ  \
# 0      Máy xăng          SUV      Xe cũ  80.000 km  Số tự động  Trong nước
# 1       Máy dầu          SUV      Xe cũ  22.000 km  Số tự động   Nhập khẩu
# 2       Máy dầu  Van/Minivan      Xe cũ  40.000 km      Số sàn  Trong nước
# 3      Máy xăng        Sedan      Xe cũ   3.200 km  Số tự động  Trong nước
# 4      Máy xăng          MPV      Xe cũ  76.000 km  Số tự động   Nhập khẩu
# ...         ...          ...        ...        ...         ...         ...
# 2964   Máy xăng    Crossover     Xe mới        NaN  Số tự động  Trong nước
# 2965    Máy dầu          SUV     Xe mới        NaN  Số tự động  Trong nước
# 2966     Hybrid          MPV     Xe mới        NaN  Số tự động  Trong nước
# 2967     Hybrid          MPV     Xe mới        NaN  Số tự động  Trong nước
# 2968   Máy xăng          SUV     Xe mới        NaN  Số tự động  Trong nước
#
#                  Tỉnh thành   Ngày đăng
# 0      Nam Từ Liêm - Hà Nội  12/07/2025
# 1        Hoàng Mai - Hà Nội  03/06/2025
# 2          Tân Phú - Tp.HCM  15/06/2025
# 3        Hoàng Mai - Hà Nội  08/04/2025
# 4     Thuận An - Bình Dương  12/02/2025
# ...                     ...         ...
# 2964       Thủ Đức - Tp.HCM  01/04/2025
# 2965       Thủ Đức - Tp.HCM  30/08/2025
# 2966       Thủ Đức - Tp.HCM  16/01/2025
# 2967       Thủ Đức - Tp.HCM  22/06/2025
# 2968       Thủ Đức - Tp.HCM  12/01/2025
#
# [2969 rows x 13 columns]

# %%
df.to_csv('old_car.csv', index=False, encoding='utf-8-sig')
new_car_df.to_csv('new_car.csv', index=False, encoding='utf-8-sig')
all_car_df.to_csv('car_data.csv', index=False, encoding='utf-8-sig')

# %%
tmp = pd.read_csv('car_data.csv')
tmp
# Out:
#                                                     URL  \
# 0     https://oto.com.vn/mua-ban-xe-hyundai-kona-ha-...
# 1     https://oto.com.vn/mua-ban-xe-ford-everest-ha-...
# 2     https://oto.com.vn/mua-ban-xe-ford-transit-hcm...
# 3     https://oto.com.vn/mua-ban-xe-mazda-3-ha-noi/s...
# 4     https://oto.com.vn/mua-ban-xe-mitsubishi-xpand...
# ...                                                 ...
# 2964  https://oto.com.vn/mua-ban-xe-mazda-cx-30-hcm/...
# 2965  https://oto.com.vn/mua-ban-xe-kia-sportage-hcm...
# 2966  https://oto.com.vn/mua-ban-xe-kia-carnival-hcm...
# 2967  https://oto.com.vn/mua-ban-xe-kia-carnival-hcm...
# 2968  https://oto.com.vn/mua-ban-xe-mazda-cx-5-hcm/k...
#
#                                      Tên xe         Giá  Số ghế  Năm SX  \
# 0         Hyundai Kona 2.0 AT Đặc biệt 2019   450000000       5    2019
# 1     Ford Everest Titanium 2.0 AT 4x2 2023  1225000000       7    2023
# 2                         Ford Transit 2022   715000000      16    2022
# 3            Mazda 3 Sedan 1.5L Luxury 2020   499000000       5    2020
# 4            Mitsubishi Xpander 1.5 MT 2019   420000000       7    2019
# ...                                     ...         ...     ...     ...
# 2964           Mazda CX-30 2.0L Luxury 2024   639000000       5    2024
# 2965       Kia Sportage 2.0D Signature 2025   910000000       5    2025
# 2966                      Kia Carnival 2025  1799000000       7    2025
# 2967                      Kia Carnival 2025  1799000000       7    2025
# 2968           Mazda CX-5 2.0L Premium 2025   784000000       5    2025
#
#      Nhiên liệu    Kiểu dáng Tình trạng   Km đã đi      Hộp số     Xuất xứ  \
# 0      Máy xăng          SUV      Xe cũ  80.000 km  Số tự động  Trong nước
# 1       Máy dầu          SUV      Xe cũ  22.000 km  Số tự động   Nhập khẩu
# 2       Máy dầu  Van/Minivan      Xe cũ  40.000 km      Số sàn  Trong nước
# 3      Máy xăng        Sedan      Xe cũ   3.200 km  Số tự động  Trong nước
# 4      Máy xăng          MPV      Xe cũ  76.000 km  Số tự động   Nhập khẩu
# ...         ...          ...        ...        ...         ...         ...
# 2964   Máy xăng    Crossover     Xe mới        NaN  Số tự động  Trong nước
# 2965    Máy dầu          SUV     Xe mới        NaN  Số tự động  Trong nước
# 2966     Hybrid          MPV     Xe mới        NaN  Số tự động  Trong nước
# 2967     Hybrid          MPV     Xe mới        NaN  Số tự động  Trong nước
# 2968   Máy xăng          SUV     Xe mới        NaN  Số tự động  Trong nước
#
#                  Tỉnh thành   Ngày đăng
# 0      Nam Từ Liêm - Hà Nội  12/07/2025
# 1        Hoàng Mai - Hà Nội  03/06/2025
# 2          Tân Phú - Tp.HCM  15/06/2025
# 3        Hoàng Mai - Hà Nội  08/04/2025
# 4     Thuận An - Bình Dương  12/02/2025
# ...                     ...         ...
# 2964       Thủ Đức - Tp.HCM  01/04/2025
# 2965       Thủ Đức - Tp.HCM  30/08/2025
# 2966       Thủ Đức - Tp.HCM  16/01/2025
# 2967       Thủ Đức - Tp.HCM  22/06/2025
# 2968       Thủ Đức - Tp.HCM  12/01/2025
#
# [2969 rows x 13 columns]

# %%
# 3. Làm sạch dữ liệu

# Kiểm tra có bao nhiêu cột không có dữ liệu
tmp.isnull().sum()
# Out:
# URL              0
# Tên xe           0
# Giá              0
# Số ghế           0
# Năm SX           0
# Nhiên liệu       0
# Kiểu dáng      308
# Tình trạng       0
# Km đã đi      1500
# Hộp số           0
# Xuất xứ         21
# Tỉnh thành       0
# Ngày đăng        0
# dtype: int64

# %%
# Tạo một bản sao để chỉnh sửa
df_cleaned = tmp.copy()

# 1. Sử dụng .str.replace() để loại bỏ các ký tự không phải số
# Dùng regex r'[. km]' để xóa cả dấu '.' và ' km'
df_cleaned['Km đã đi'] = df_cleaned['Km đã đi'].replace(r'[. km]', '', regex=True)
# df_cleaned['Km đã đi'] = df_cleaned['Km đã đi'].replace(".", "")

# 2. Chuyển cột sang dạng số
# errors='coerce' sẽ biến giá trị 'nan' hoặc chuỗi rỗng thành NaN
df_cleaned['Km đã đi'] = pd.to_numeric(df_cleaned['Km đã đi'], errors='coerce')

print(df_cleaned[['Tình trạng', 'Km đã đi']].head())
# Out:
#   Tình trạng  Km đã đi
# 0      Xe cũ   80000.0
# 1      Xe cũ   22000.0
# 2      Xe cũ   40000.0
# 3      Xe cũ    3200.0
# 4      Xe cũ   76000.0

# %%
# Xử lý giá trị NaN

# 1. Tính trung vị (median) của 'Km đã đi' CHỈ cho 'Xe cũ'
# lọc ra các xe cũ và không bị NaN ở cột 'Km đã đi' để tính
median_km_cu = df_cleaned[df_cleaned['Tình trạng'] == 'Xe cũ']['Km đã đi'].median()
print(f"Trung vị 'Km đã đi' của xe cũ là: {median_km_cu}")

# 2. Điền giá trị
# Dùng .loc[<điều kiện hàng>, <tên cột>] = <giá trị>

# Điền 0 cho xe mới bị thiếu
df_cleaned.loc[(df_cleaned['Tình trạng'] == 'Xe mới') & (df_cleaned['Km đã đi'].isnull()), 'Km đã đi'] = 0

# Điền median cho xe cũ bị thiếu
df_cleaned.loc[(df_cleaned['Tình trạng'] == 'Xe cũ') & (df_cleaned['Km đã đi'].isnull()), 'Km đã đi'] = median_km_cu

df_cleaned.isnull().sum()
# Out:
# Trung vị 'Km đã đi' của xe cũ là: 60000.0
# URL             0
# Tên xe          0
# Giá             0
# Số ghế          0
# Năm SX          0
# Nhiên liệu      0
# Kiểu dáng     308
# Tình trạng      0
# Km đã đi        0
# Hộp số          0
# Xuất xứ        21
# Tỉnh thành      0
# Ngày đăng       0
# dtype: int64

# %%
# Xử lý giá trị thiếu cho cột Kiểu dáng và Xuất xứ

# Thay thế giá trị thiếu bằng giá trị phổ biến nhất (mode)
# .mode()[0] trả về giá trị phổ biến nhất

mode_XX = df_cleaned['Xuất xứ'].mode()[0]
print(f'Giá trị phổ biến nhất ở cột Xuất xứ là: {mode_XX}')

mode_KD = df_cleaned['Kiểu dáng'].mode()[0]
print(f'Giá trị phổ biến nhất ở cột Kiểu dáng là: {mode_KD}')
# Out:
# Giá trị phổ biến nhất ở cột Xuất xứ là: Trong nước
# Giá trị phổ biến nhất ở cột Kiểu dáng là: SUV

# %%
# Lặp qua các cột phân loại có thể bị thiếu
for col in ['Xuất xứ', 'Kiểu dáng']:
    if df_cleaned[col].isnull().any():
         # Kiểm tra xem cột có bị thiếu không

        mode_value = df_cleaned[col].mode()[0]

        # .fillna() để điền vào các giá trị NaN
        df_cleaned[col] = df_cleaned[col].fillna(mode_value)

print('Số cột không có giá trị là:')
print(df_cleaned.isnull().sum())
# Out:
# Số cột không có giá trị là:
# URL           0
# Tên xe        0
# Giá           0
# Số ghế        0
# Năm SX        0
# Nhiên liệu    0
# Kiểu dáng     0
# Tình trạng    0
# Km đã đi      0
# Hộp số        0
# Xuất xứ       0
# Tỉnh thành    0
# Ngày đăng     0
# dtype: int64

# %%
# Kiểm tra phòng trường hợp Số ghế = 0 (vô lý)
print(f'Có {len(df_cleaned[df_cleaned['Số ghế'] == 0])} xe có Số ghế = 0')
# Out:
# Có 312 xe có Số ghế = 0

# %%
# Cần xử lý các giá trị Số ghế = 0 này bằng việc thay bằng mode
mode_so_ghe = df_cleaned['Số ghế'].mode()[0]
print(f'Giá trị phổ biến nhất ở cột Số ghế là: {mode_so_ghe}')

# Thay chúng vào các cột = 0
df_cleaned.loc[df_cleaned['Số ghế'] == 0, 'Số ghế'] = mode_so_ghe

print(f'Có {len(df_cleaned[df_cleaned['Số ghế'] == 0])} xe có Số ghế = 0')
# Out:
# Giá trị phổ biến nhất ở cột Số ghế là: 5
# Có 0 xe có Số ghế = 0

# %%
# Đã xử lý toàn bộ dữ liệu
# => Lưu DataFrame đã làm sạch
df_cleaned.to_csv('car_data_cleaned.csv', index=False, encoding='utf-8-sig')

# %%
# 4. Phân tích ngoại lai (cho cột 'Giá')
df_cleaned = pd.read_csv('car_data_cleaned.csv')
# Lấy các cột số để phân tích
numeric_cols = ['Giá', 'Số ghế', 'Năm SX', 'Km đã đi']
data_numeric = df_cleaned[numeric_cols]

# Tính Q1 (phân vị 25%) và Q3 (phân vị 75%)
Q1 = data_numeric['Giá'].quantile(0.25)
Q3 = data_numeric['Giá'].quantile(0.75)
IQR = Q3 - Q1 # Interquartile Range

# Xác định ngưỡng
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"Ngưỡng ngoại lai trên (cột Giá): {upper_bound}")
print(f"Ngưỡng ngoại lai dưới (cột Giá): {lower_bound}")

# Đếm số lượng ngoại lai
outliers_count = ((data_numeric['Giá'] < lower_bound) | (data_numeric['Giá'] > upper_bound)).sum()
print(f"Phát hiện {outliers_count} ngoại lai trong cột 'Giá'.")
# Chiến lược: Sẽ không xóa, nhưng sẽ ưu tiên dùng RobustScaler ở bước 5
# Out:
# Ngưỡng ngoại lai trên (cột Giá): 2072500000.0
# Ngưỡng ngoại lai dưới (cột Giá): -523500000.0
# Phát hiện 395 ngoại lai trong cột 'Giá'.

# %%
# 4. Phân tích ngoại lai (cho cột 'Số ghế')

# Tính Q1 (phân vị 25%) và Q3 (phân vị 75%)
Q1 = data_numeric['Số ghế'].quantile(0.25)
Q3 = data_numeric['Số ghế'].quantile(0.75)
IQR = Q3 - Q1 # Interquartile Range

# Xác định ngưỡng
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"Ngưỡng ngoại lai trên (cột Số ghế): {upper_bound}")
print(f"Ngưỡng ngoại lai dưới (cột Số ghế): {lower_bound}")

# Đếm số lượng ngoại lai
outliers_count = ((data_numeric['Số ghế'] < lower_bound) | (data_numeric['Số ghế'] > upper_bound)).sum()
print(f"Phát hiện {outliers_count} ngoại lai trong cột 'Số ghế'.")
# Out:
# Ngưỡng ngoại lai trên (cột Số ghế): 5.0
# Ngưỡng ngoại lai dưới (cột Số ghế): 5.0
# Phát hiện 868 ngoại lai trong cột 'Số ghế'.

# %%
# 4. Phân tích ngoại lai (cho cột 'Km đã đi')

# Tính Q1 (phân vị 25%) và Q3 (phân vị 75%)
Q1 = data_numeric['Km đã đi'].quantile(0.25)
Q3 = data_numeric['Km đã đi'].quantile(0.75)
IQR = Q3 - Q1 # Interquartile Range

# Xác định ngưỡng
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"Ngưỡng ngoại lai trên (cột Km đã đi): {upper_bound}")
print(f"Ngưỡng ngoại lai dưới (cột Km đã đi): {lower_bound}")

# Đếm số lượng ngoại lai
outliers_count = ((data_numeric['Km đã đi'] < lower_bound) | (data_numeric['Km đã đi'] > upper_bound)).sum()
print(f"Phát hiện {outliers_count} ngoại lai trong cột 'Km đã đi'.")
# Out:
# Ngưỡng ngoại lai trên (cột Km đã đi): 150000.0
# Ngưỡng ngoại lai dưới (cột Km đã đi): -90000.0
# Phát hiện 87 ngoại lai trong cột 'Km đã đi'.

# %%
# 4. Phân tích ngoại lai (cho cột 'Năm SX')

# Tính Q1 (phân vị 25%) và Q3 (phân vị 75%)
Q1 = data_numeric['Năm SX'].quantile(0.25)
Q3 = data_numeric['Năm SX'].quantile(0.75)
IQR = Q3 - Q1 # Interquartile Range

# Xác định ngưỡng
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"Ngưỡng ngoại lai trên (cột Năm SX): {upper_bound}")
print(f"Ngưỡng ngoại lai dưới (cột Năm SX): {lower_bound}")

# Đếm số lượng ngoại lai
outliers_count = ((data_numeric['Năm SX'] < lower_bound) | (data_numeric['Năm SX'] > upper_bound)).sum()
print(f"Phát hiện {outliers_count} ngoại lai trong cột 'Năm SX'.")
# Out:
# Ngưỡng ngoại lai trên (cột Năm SX): 2032.5
# Ngưỡng ngoại lai dưới (cột Năm SX): 2012.5
# Phát hiện 158 ngoại lai trong cột 'Năm SX'.

# %%
for col in numeric_cols:
    sns.boxplot(df_cleaned[col])
    plt.title(f"Boxplot thể hiện giá trị ngoại lai của {col}")
    plt.grid()
    plt.show()

# %%
## Hàm phát hiện các điểm dữ liệu outliers trong các cột dữ liệu dạng số sử dụng IQR
def detect_outliers(df):
    numeric_cols = df.select_dtypes(include=["float", "int64"]).columns.tolist()
    outlier_indices = set()
    for col in numeric_cols:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        min_whisker = Q1 - 1.5*IQR
        max_whisker = Q3 + 1.5*IQR
        outliers = df[(df[col]<min_whisker) | (df[col]>max_whisker)].index
        outlier_indices.update(outliers)
    return list(outlier_indices)

# %%
# Kích thước df trước khi loại bỏ outliers
df_cleaned.shape
# Out:
# (2969, 13)

# %%
# Lấy index outliers
outlier_idx = detect_outliers(df_cleaned)
print(f'Số outliers là: {len(outlier_idx)}')
# # Lọc DataFrame không chứa outliers
# df_no_outliers = df_cleaned.drop(index=outlier_idx)

# # Ta được kích thước DataFrame sau khi loại bỏ outliers:
# df_no_outliers.shape
# Out:
# Số outliers là: 1281

# %%
# => Có gần nửa data là outliers
# => Không nên loại bỏ
# => Sử dụng RobustScaler, nó chỉ quan tâm đến Median và IQR, không bị ảnh hưởng bởi các giá trị siêu lớn

# 5. Chuẩn hóa dữ liệu
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# 1. Khởi tạo các "Scaler"
scaler_standard = StandardScaler()
scaler_minmax = MinMaxScaler()
scaler_robust = RobustScaler() # Lựa chọn ưu tiên vì có ngoại lai

# 2. Áp dụng StandardScaler (Mean=0, Std=1)
# .fit_transform() học tham số (mean, std) và biến đổi dữ liệu
df_scaled_std = scaler_standard.fit_transform(data_numeric)
print("\n5 dòng đầu sau khi dùng StandardScaler:")
print(pd.DataFrame(df_scaled_std, columns=numeric_cols).head())

# 3. Áp dụng MinMaxScaler (Range [0, 1])
df_scaled_minmax = scaler_minmax.fit_transform(data_numeric)
print("\n5 dòng đầu sau khi dùng MinMaxScaler:")
print(pd.DataFrame(df_scaled_minmax, columns=numeric_cols).head())

# 4. Áp dụng RobustScaler (Kháng ngoại lai)
# Phương pháp này dùng Median và IQR, ít bị ảnh hưởng bởi giá trị quá lớn/quá nhỏ
df_scaled_robust = scaler_robust.fit_transform(data_numeric)
print("\n5 dòng đầu sau khi dùng RobustScaler (ĐỀ XUẤT):")
print(pd.DataFrame(df_scaled_robust, columns=numeric_cols).head())
# Out:
# 5 dòng đầu sau khi dùng StandardScaler:
#         Giá    Số ghế    Năm SX  Km đã đi
# 0 -0.420771 -0.264062 -0.608760  0.677063
# 1  0.015279  1.081860  0.289219 -0.205140
# 2 -0.271670  7.138511  0.064725  0.068647
# 3 -0.393201 -0.264062 -0.384265 -0.491096
# 4 -0.437650  1.081860 -0.608760  0.616222
#
# 5 dòng đầu sau khi dùng MinMaxScaler:
#         Giá    Số ghế    Năm SX  Km đã đi
# 0  0.015880  0.111111  0.750000  0.082474
# 1  0.044836  0.185185  0.916667  0.022680
# 2  0.025781  0.518519  0.875000  0.041237
# 3  0.017710  0.111111  0.791667  0.003299
# 4  0.014759  0.185185  0.750000  0.078351
#
# 5 dòng đầu sau khi dùng RobustScaler (ĐỀ XUẤT):
#         Giá  Số ghế  Năm SX  Km đã đi
# 0 -0.322034     0.0    -1.0  1.333333
# 1  0.872111     2.0    -0.2  0.366667
# 2  0.086287    11.0    -0.4  0.666667
# 3 -0.246533     0.0    -0.8  0.053333
# 4 -0.368259     2.0    -1.0  1.266667

# %%
# MinMaxScaler "kẹp" mọi giá trị vào khoảng từ 0 đến 1.
# StandardScaler biến đổi sao cho giá trị trung bình (mean) của cột là 0 và độ lệch chuẩn là 1.
# RobustScaler biến đổi sao cho trung vị (median) là 0 và được co giãn bởi IQR.

# Chương 4: Dùng thuật toán K-means để phân nhãn dữ liệu
from sklearn.cluster import KMeans

# df_scaled_robust là data đã chuẩn hóa bằng RobustScaler
wcss = [] # Sum of squared distances
K_range = range(1, 11) # Thử từ 1 đến 10 nhãn

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(df_scaled_robust)
    wcss.append(kmeans.inertia_) # inertia_ là tổng WCSS

# Vẽ đồ thị
plt.figure(figsize=(10, 6))
plt.plot(K_range, wcss, marker='o', linestyle='--')
plt.xlabel('Số lượng nhãn (K)')
plt.ylabel('WCSS (Inertia)')
plt.title('Phương pháp Khuỷu tay (Elbow Method)')
plt.grid(True)

# %%
# Từ biểu đồ, ta quyết định chọn cả K=3 và K=4 để so sánh
k_toi_uu = 3

kmeans_final = KMeans(n_clusters=k_toi_uu, random_state=42, n_init=10)
kmeans_final.fit(df_scaled_robust)

# Lấy nhãn của từng dòng dữ liệu
labels = kmeans_final.labels_
labels
# Out:
# array([2, 2, 2, ..., 2, 2, 2], dtype=int32)

# %%
# df_cleaned là DataFrame TRƯỚC chuẩn hóa
df_cleaned['Nhãn'] = labels

# xem đặc điểm trung bình của từng nhãn
cluster_analysis = df_cleaned.groupby('Nhãn')[['Giá', 'Số ghế', 'Năm SX', 'Km đã đi']].mean()
print(cluster_analysis)

print("\nSố lượng xe trong mỗi nhãn:")
print(df_cleaned['Nhãn'].value_counts())
# Out:
#                Giá    Số ghế       Năm SX      Km đã đi
# Nhãn
# 0     3.361485e+09  5.427326  2023.590116  10246.345930
# 1     9.921791e+09  5.164179  2023.313433   7807.940299
# 2     6.783766e+08  5.393667  2021.417123  39606.157545
#
# Số lượng xe trong mỗi nhãn:
# Nhãn
# 2    2558
# 0     344
# 1      67
# Name: count, dtype: int64

# %%
# Xét trường hợp K=4
k_toi_uu = 4

kmeans_final = KMeans(n_clusters=k_toi_uu, random_state=42, n_init=10)
kmeans_final.fit(df_scaled_robust)

# Lấy nhãn của từng dòng dữ liệu (0, 1, 2, hoặc 3)
labels = kmeans_final.labels_
labels
# Out:
# array([0, 2, 0, ..., 2, 2, 2], dtype=int32)

# %%
df_cleaned['Nhãn'] = labels

# đặc điểm trung bình của từng nhãn
cluster_analysis = df_cleaned.groupby('Nhãn')[['Giá', 'Số ghế', 'Năm SX', 'Km đã đi']].mean()
print(cluster_analysis)

# Xem số lượng xe trong mỗi nhãn
print("Số lượng xe trong mỗi nhãn:")
print(df_cleaned['Nhãn'].value_counts())
# Out:
#                Giá    Số ghế       Năm SX       Km đã đi
# Nhãn
# 0     4.690766e+08  5.802469  2015.534979  110565.757202
# 1     3.470125e+09  5.448598  2023.498442   10930.660436
# 2     7.784353e+08  5.229358  2023.776039   11185.167296
# 3     9.971076e+09  5.166667  2023.287879    7926.242424
# Số lượng xe trong mỗi nhãn:
# Nhãn
# 2    1853
# 0     729
# 1     321
# 3      66
# Name: count, dtype: int64

# %%
# Nhận xét kết quả phân cụm K-means:
# - K=3 (Tốt, nhưng chưa đủ): Đã tốt hơn. Nó chia ra 3 nhóm:

# + Nhãn 2: "Xe phổ thông/cũ" (Giá 678tr, Sx 2021, 39k km)
# + Nhãn 0: "Xe sang" (Giá 3.3 tỷ)
# + Nhãn 1: "Xe siêu sang" (Giá 9.9 tỷ)

# - K=4 (Rất tốt - Lựa chọn tối ưu): Đây là lựa chọn tốt nhất vì nó lấy Nhãn 2 (Xe phổ thông) của K=3 và tách nó ra làm 2 nhóm con có ý nghĩa rõ rệt:

# + Nhóm "Xe cũ/chạy nhiều" (Giá 469tr, SX 2015, 110k km)
# + Nhóm "Xe mới/lướt phổ thông" (Giá 778tr, SX 2023, 11k km)

# => Việc tách được 2 nhóm này cho thấy K=4 cung cấp một cái nhìn chi tiết và giá trị hơn hẳn so với K=3. Biểu đồ khuỷu tay (elbow plot) cũng cho thấy K=4 là một điểm "gãy" hợp lý.

## Kết luận: 4 Phân khúc thị trường xe (Diễn giải K=4)
# Dựa trên kết quả K=4, chúng ta có thể kết luận thị trường xe trong dữ liệu này được chia làm 4 phân khúc chính:

# Phân khúc 1: "Xe Phổ thông Mới / Lướt" (Nhãn 2) 
# Số lượng: 1853 xe (Lớn nhất thị trường)
# Đặc điểm:
# Giá: ~ 778 triệu (tầm trung)
# Năm SX: ~ 2023.7 (Rất mới)
# Km đã đi: ~ 11.000 km (Chạy rất ít, xe lướt)
# Chân dung: Đây là nhóm xe phổ thông (5 chỗ) vừa mới mua, chạy lướt, chiếm phần lớn thị trường.

# Phân khúc 2: "Xe Cũ / Chạy nhiều" (Nhãn 0)
# Số lượng: 729 xe
# Đặc điểm:
# Giá: ~ 469 triệu (Rẻ nhất)
# Năm SX: ~ 2015.5 (Đời sâu nhất)
# Km đã đi: ~ 110.000 km (Chạy nhiều nhất)
# Chân dung: Đây là phân khúc xe cũ, đã sử dụng lâu năm, giá rẻ, thường là xe 5-7 chỗ (trung bình 5.8 ghế).

# Phân khúc 3: "Xe Sang" (Nhãn 1)
# Số lượng: 321 xe
# Đặc điểm:
# Giá: ~ 3.47 tỷ (Cao)
# Năm SX: ~ 2023.5 (Rất mới)
# Km đã đi: ~ 10.900 km (Rất ít)
# Chân dung: Phân khúc xe sang, xe lướt, giá cao.

# Phân khúc 4: "Xe Siêu Sang / Đặc biệt" (Nhãn 3)
# Số lượng: 66 xe (Nhóm nhỏ và đặc biệt)
# Đặc điểm:
# Giá: ~ 9.97 tỷ (Rất cao, nhóm ngoại lai)
# Năm SX: ~ 2023.3 (Rất mới)
# Km đã đi: ~ 7.900 km (Siêu ít)
# Chân dung: Đây là nhóm xe siêu sang, có thể coi là các "ngoại lai" (outliers) về giá. K-means (nhờ RobustScaler) đã tách riêng nhóm này ra rất thành công.

# %%
df_cleaned.to_csv('car_clean_with_labels.csv', index=False, encoding='utf-8-sig')

# %%
plt.plot(df_cleaned['Năm SX'], df_cleaned['Giá'], 'o')
plt.title('Biểu đồ 15: Giá xe theo năm sản xuất')
plt.xlabel('Năm SX')
plt.ylabel('Giá xe (chục tỷ VND)')
plt.grid()
plt.savefig('15_price_vs_year.png')

# %%
plt.plot(df_cleaned['Số ghế'], df_cleaned['Giá'], '*')
plt.title('Biểu đồ 16: Giá xe theo số ghế')
plt.xlabel('Số ghế')
plt.ylabel('Giá xe (chục tỷ VND)')
plt.grid()
plt.savefig('16_price_vs_seats.png')

# %%
plt.plot(df_cleaned['Km đã đi'], df_cleaned['Giá'], 'x')
plt.title('Biểu đồ 17: Giá xe theo Km đã đi')
plt.xlabel('Km đã đi')
plt.ylabel('Giá xe (chục tỷ VND)')
plt.grid()
plt.savefig('17_price_vs_km.png')

# %%
sns.scatterplot(x='Km đã đi', y='Giá', hue='Nhãn', data=df_cleaned, palette='Set1')
plt.title('Biểu đồ 18: Giá xe theo Km đã đi và Nhãn phân cụm')
plt.grid()
plt.savefig('18_price_vs_km_clusters.png')
plt.show()

# %%
sns.scatterplot(x='Số ghế', y='Giá', hue='Nhãn', data=df_cleaned, palette='Set1')
plt.title('Biểu đồ 19: Giá xe theo Số ghế và Nhãn phân cụm')
plt.grid()
plt.savefig('19_price_vs_seats_clusters.png')
plt.show()

# %%
df_cleaned = pd.read_csv('car_clean_with_labels.csv')
df_cleaned['Giá_log'] = np.log1p(df_cleaned['Giá'])

sns.histplot(
    df_cleaned['Giá_log'], 
    kde=True,  # kde=True sẽ vẽ thêm đường ước lượng mật độ
    bins=50    # Chia thành 50 cột
)

plt.title('Biểu đồ 1: Phân bổ Giá xe (trên thang Logarit)', fontsize=16)
plt.xlabel('Log(Giá + 1)', fontsize=12)
plt.ylabel('Số lượng xe', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)

plt.savefig('1_price_distribution_log.png')

# %%
df_cleaned['Km_log'] = np.log1p(df_cleaned['Km đã đi'])

sns.scatterplot(
    data=df_cleaned, 
    x='Km_log',        # Trục hoành
    y='Giá_log',        # Trục tung
    hue='Nhãn',        # 'hue' là tham số quan trọng để TÔ MÀU theo cụm
    palette='Set1',  # Bảng màu (bạn có thể đổi thành 'Set1', 'coolwarm'...)
    alpha=0.8,          # Độ trong suốt của điểm
    s=50                # Kích thước điểm
)

plt.title('Biểu đồ 2: Trực quan 4 Phân khúc (Nhãn) K-means', fontsize=16)
plt.xlabel('Log(Km đã đi + 1)', fontsize=12)
plt.ylabel('Log(Giá + 1)', fontsize=12)
plt.legend(title='Phân khúc (Nhãn)', title_fontsize='13', fontsize='11')
plt.grid(True, linestyle='--', alpha=0.6)

plt.savefig('2_kmeans_scatter_plot.png')

# %%
sns.countplot(
    data=df_cleaned, 
    x='Xuất xứ', 
    # Sắp xếp các cột theo thứ tự từ nhiều đến ít
    order=df_cleaned['Xuất xứ'].value_counts().index,
    palette='Set2'
)

plt.title('Biểu đồ 3: Số lượng xe theo Xuất xứ', fontsize=16)
plt.xlabel('Xuất xứ', fontsize=12)
plt.ylabel('Số lượng xe', fontsize=12)

plt.savefig('3_origin_bar_chart.png')
# Out:
# /var/folders/gw/zrbmxjtx44x28l429ym8bsx80000gn/T/ipykernel_7977/3029305962.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %%
sns.boxplot(
    data=df_cleaned, 
    x='Tình trạng',  # Nhóm theo 'Tình trạng'
    y='Giá_log',    # So sánh phân bổ của 'Giá_log'
    palette='Pastel1'
)

plt.title('Biểu đồ 4: So sánh Phân bổ Giá (Log) theo Tình trạng xe', fontsize=16)
plt.xlabel('Tình trạng', fontsize=12)
plt.ylabel('Log(Giá + 1)', fontsize=12)
plt.grid(True, linestyle='--', axis='y', alpha=0.6)

plt.savefig('4_status_price_boxplot.png')
# Out:
# /var/folders/gw/zrbmxjtx44x28l429ym8bsx80000gn/T/ipykernel_7977/2924073332.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
from mpl_toolkits.mplot3d import Axes3D # Thư viện riêng cho 3D

# Lấy lại các cột số (để dùng cho heatmap)
numeric_cols = ['Giá', 'Số ghế', 'Năm SX', 'Km đã đi']

# %%
# --- Biểu đồ 5: Correlation Heatmap (Ma trận tương quan) ---
corr = df_cleaned[numeric_cols].corr() 
sns.heatmap(
    corr, 
    annot=True,     # Hiện thị số
    cmap='coolwarm',# Bảng màu
    fmt='.2f'       # Định dạng số
)
plt.title('Biểu đồ 5: Ma trận tương quan giữa các biến số', fontsize=16)
plt.savefig('5_correlation_heatmap.png')
plt.show()

# %%
# --- Biểu đồ 6: Pair Plot (Biểu đồ cặp, tô màu theo cụm) ---
pairplot_data = df_cleaned[['Giá_log', 'Km_log', 'Năm SX', 'Nhãn', 'Số ghế']]
g = sns.pairplot(
    pairplot_data, 
    hue='Nhãn',         # Tô màu theo cụm
    palette='Set1', # Bảng màu
    corner=True        # Chỉ vẽ nửa dưới ma trận
)
g.fig.suptitle('Biểu đồ 6: Mối quan hệ cặp các biến (Tô màu theo Nhãn)', y=1.02, fontsize=16)
plt.savefig('6_pairplot_clusters.png')
plt.show()

# %%
# --- Biểu đồ 7: Violin Plot (Giá vs. Kiểu dáng) ---
# Lọc ra 5 kiểu dáng phổ biến nhất
top_5_styles = df_cleaned['Kiểu dáng'].value_counts().nlargest(5).index
df_filtered_styles = df_cleaned[df_cleaned['Kiểu dáng'].isin(top_5_styles)]

sns.violinplot(
    data=df_filtered_styles, 
    x='Kiểu dáng', 
    y='Giá_log', 
    palette='Set3',
    order=top_5_styles # Sắp xếp theo thứ tự phổ biến
)
plt.title('Biểu đồ 7: Phân bổ Giá (Log) theo 5 Kiểu dáng phổ biến nhất', fontsize=16)
plt.xlabel('Kiểu dáng', fontsize=12)
plt.ylabel('Log(Giá + 1)', fontsize=12)
plt.savefig('7_violin_plot_style_price.png')
plt.show()
# Out:
# /var/folders/gw/zrbmxjtx44x28l429ym8bsx80000gn/T/ipykernel_7977/4224136240.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(

# %%
# --- Biểu đồ 8: 2D KDE Plot (Biểu đồ mật độ 2D) ---
sns.kdeplot(
    data=df_cleaned, 
    x='Km_log', 
    y='Giá_log', 
    hue='Nhãn',     # Vẽ mật độ cho từng cụm
    fill=True,     # Tô màu nền
    palette='Set1', 
    alpha=0.6
)
plt.title('Biểu đồ 8: Biểu đồ mật độ 2D của các Phân khúc', fontsize=16)
plt.xlabel('Log(Km đã đi + 1)', fontsize=12)
plt.ylabel('Log(Giá + 1)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.savefig('8_2d_kde_clusters.png')
plt.show()

# %%
# --- Biểu đồ 9: Joint Plot (Giá vs. Năm SX) ---
g = sns.jointplot(
    data=df_cleaned, 
    x='Năm SX', 
    y='Giá_log', 
    kind='hex', # Hiển thị mật độ bằng các ô lục giác (hexbins)
    cmap='Blues',  # Bảng màu
    height=6       # Kích thước
)
g.fig.suptitle('Biểu đồ 9: Mối quan hệ Giá (Log) và Năm SX', y=1.02, fontsize=16)
plt.savefig('9_jointplot_year_price.png')
plt.show()

# %%
# --- Biểu đồ 10: 3D Scatter Plot (Biểu đồ phân tán 3D) ---
print("Đang tạo biểu đồ 3D...")
fig = plt.figure(figsize=(12, 9))
ax = fig.add_subplot(111, projection='3d') # Tạo trục 3D

# Lấy nhãn cụm (0, 1, 2, 3) để làm màu
colors = df_cleaned['Nhãn'].astype(int)

scatter = ax.scatter(
    df_cleaned['Km_log'],  # Trục X
    df_cleaned['Năm SX'],  # Trục Y
    df_cleaned['Giá_log'], # Trục Z
    c=colors,            # Màu sắc theo cụm
    cmap='Set1',        # Bảng màu
    s=10,                  # Kích thước điểm
    alpha=0.7
)

# Đặt tên các trục
ax.set_xlabel('Log(Km đã đi)')
ax.set_ylabel('Năm SX')
ax.set_zlabel('Log(Giá)')
plt.title('Biểu đồ 10: Phân cụm 3D (Giá, Km, Năm SX)', fontsize=16)

# Tạo chú giải (legend)
legend_elements = scatter.legend_elements()
legend = ax.legend(legend_elements[0], legend_elements[1], title='Nhãn')
ax.add_artist(legend)

plt.savefig('10_3d_scatter_plot.png')
plt.show()
# Out:
# Đang tạo biểu đồ 3D...

# %%
df_labeled = pd.read_csv('car_clean_with_labels.csv')

cat_cols = [c for c in ['Xuất xứ','Kiểu dáng','Hộp số','Nhiên liệu'] if c in df_labeled.columns]
i = 11
for c in cat_cols:
    plt.figure(figsize=(10,5))
    ct = pd.crosstab(df_labeled[c], df_labeled['Nhãn'])
    ct = ct.apply(lambda x: x/x.sum(), axis=0)  # tỉ lệ trong từng nhãn
    ct.plot(kind='bar', stacked=True, colormap='tab20')
    plt.title(f'Biểu đồ {i}: Tỉ lệ {c} trong từng nhãn (stacked)')
    plt.xlabel(c); plt.ylabel('Tỉ lệ'); 
    plt.legend(title='Nhãn', bbox_to_anchor=(1.02, 1), loc='upper left')
    plt.tight_layout(); 
    plt.savefig(f'{i}_viz_cluster_cat_{c}.png'); 
    plt.show()
    i += 1
